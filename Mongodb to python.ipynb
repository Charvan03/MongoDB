# %%
import pymongo

# %%
connection = pymongo.MongoClient("mongodb://Charvan:Saravana321@ac-sj2ytw3-shard-00-00.hcvyivv.mongodb.net:27017,ac-sj2ytw3-shard-00-01.hcvyivv.mongodb.net:27017,ac-sj2ytw3-shard-00-02.hcvyivv.mongodb.net:27017/?ssl=true&replicaSet=atlas-i7baj4-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
S = connection['sample_mflix']

# %%
S_Movies = S['movies']

# %%
for i in S_Movies.find({'$and':[{'genres':{'$in':['Comedy','Thriller','Romance','Horror']}},{'awards.wins':{'$lte':1}},{'imdb.rating':{'$gte':7}},{'tomatoes.viewer.rating':{'$gte':3.3}}]},{'_id':0,'plot':1,'languages':1,'year':1}):
  print(i)
# Out:
# {'plot': 'Cartoon figures announce, via comic strip balloons, that they will move - and move they do, in a wildly exaggerated style.', 'languages': ['English'], 'year': 1911}
# {'plot': 'The cartoonist, Winsor McCay, brings the Dinosaurus back to life in the figure of his latest creation, Gertie the Dinosaur.', 'languages': ['English'], 'year': 1914}
# {'plot': 'Charlie is an immigrant who endures a challenging voyage and gets into trouble as soon as he arrives in America.', 'languages': ['English'], 'year': 1917}
# {'plot': "A frail waif, abused by her brutal boxer father in London's seedy Limehouse District, is befriended by a sensitive Chinese immigrant with tragic consequences.", 'year': 1919}
# {'plot': 'A penniless young man tries to save an heiress from kidnappers and help her secure her inheritance.', 'languages': ['English'], 'year': 1919}
# ...

# %%
B = []
for i in S_Movies.find({'$and':[{'genres':{'$in':['Comedy','Thriller','Romance','Horror']}},{'awards.wins':{'$lte':1}},{'imdb.rating':{'$gte':7}},{'tomatoes.viewer.rating':{'$gte':3.3}}]},{'_id':0,'plot':1,'languages':1,'year':1}):
 B.append(i)

# %%
import pandas as pd

# %%
Df = pd.DataFrame(B)

# %%
Df
# Out:
#                                                    plot  \
# 0     Cartoon figures announce, via comic strip ball...
# 1     The cartoonist, Winsor McCay, brings the Dinos...
# 2     Charlie is an immigrant who endures a challeng...
# 3     A frail waif, abused by her brutal boxer fathe...
# 4     A penniless young man tries to save an heiress...
# ...                                                 ...
# 1063  Young-Hwa Yoon, once a top national news ancho...
# 1064  To the folks in Conway, South Carolina, Duncan...
# 1065  A desk-bound CIA analyst volunteers to go unde...
# 1066  Master monologist Matt Smith My Last Year With...
# 1067  A beautiful girl who has everything. Charming,...
#
#                                languages  year
# 0                              [English]  1911
# 1                              [English]  1914
# 2                              [English]  1917
# 3                                    NaN  1919
# 4                              [English]  1919
# ...

# %%
Df.to_csv('file.csv')
